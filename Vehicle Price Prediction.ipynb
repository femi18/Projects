# %% [markdown]
# # Vehicle Price Regression
#
# For this capstone project, I have chosen a dataset of sold vehicles in the last 12 months from a local car dealership.
# The dataset contains 2174 sold vehicles, each with several feature types, including; float, integer, and categorical. A regression model would be built to estimate a vehicle's sale price. This model can assist the dealership properly price their vehicles in active inventory.
#
# Features in the data as follows;
#
# Red/Black - Number of vehicles not appraised or booked out through the software
#
# Carfax Has Report -  vehicle has a carfax report generated
#
# Carfax Has Manufacturer Recall - indicates if there is an OEM recall on the vehicle
#
# Carfax Has Warnings - There is an alert on the vehicle report
#
# Carfax Has Problems - vehicle has had major issues reported
#
# Photos - vehicle has marketing photos
#
# Year - Model year of the vehicle
#
# Vehicle - Model and trim/series of the vehicle
#
# VIN - Vehicle identification number
#
# Class - Vehicle body classification
#
# Class_type - subcategories of the vehicle class
#
# Certified - certified pre-owned vehicle
#
# Deleted Date  - sold date of vehicle
#
# Status - if the vehicle was added via an appraisal or through the Dealer Management System
#
# Recall Status  - if the vehicle has an open or closed recall
#
# Age - Vehicle Days in inventory
#
# Body - number of vehicle doors and class
#
# Color - vehicle color
#
# Disp - Vehicle disposition
#
# Price - Price vehicle was sold for
#
# Book  - vehicle book value depending on price guide selected
#
# Cost  - amount dealership paid for the vehicle
#
# Odometer  - the odometer reading when vehicle was sold
#
# Overall -    available supply of similarly configured vehicles
#
# Like Mine - Days to sell vehicles like mine based on the market

# %%
# First, lets load Helpful Packages
import pandas as pd
import numpy as np
import numpy as np # for linear algebra
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
import statistics
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# %%
excel_file = 'Deleted_report.xls'
data_original = pd.read_excel(excel_file)
data = pd.read_excel(excel_file)
data.head()
# Out:
#    Red/Black Carfax Has\nReport Carfax Has\nManufacturer\nRecall  \
# 0        NaN                NaN                              NaN
# 1        NaN                Yes                              NaN
# 2        NaN                NaN                              NaN
# 3        NaN                NaN                              NaN
# 4        NaN                NaN                              NaN
#
#   Carfax Has\nWarnings Carfax Has\nProblems  Photos  Year  \
# 0                  NaN                  NaN     NaN  2018
# 1                  NaN                  NaN     NaN  2015
# 2                  NaN                  NaN     NaN  2018
# 3                  NaN                  NaN     NaN  2017
# 4                  NaN                  NaN     NaN  2014
#
#                                 Vehicle                VIN Class    ...      \
# 0         Mercedes-Benz GLS 450 4MATIC®  4JGDF6EE8JB069995   SUV    ...
# 1   Mercedes-Benz C-Class C 300 4MATIC®  55SWF4KB3FU048731   Car    ...
# 2   Mercedes-Benz S-Class S 450 4MATIC®  WDDUG6EB9JA374697   Car    ...
# 3           Mercedes-Benz Sprinter 3500  WD3PF4CC4HP376370   Van    ...
# 4  Mercedes-Benz M-Class ML 350 4MATIC®  4JGDA5HB9EA347406   SUV    ...
#
#   Age              Body           Color    Disp     Price     Book     Cost  \
# 0   1  4D Sport Utility  Obsidian Black  Retail   76164.0      NaN  76514.0
# 1   1          4D Sedan     Polar White  Retail       NaN  17874.0      NaN
# 2   1          4D Sedan   Gray Metallic  Retail  116148.0      NaN      NaN
# 3   1      3D Cargo Van    Arctic White  Retail   49526.0  39546.0      NaN
# 4   1  4D Sport Utility           Brown  Retail   25117.0      NaN      NaN
#
#   Odometer Overall  Like Mine
# 0     45.0     NaN        NaN
# 1  47525.0    35.0       33.0
# 2     42.0     NaN        NaN
# 3      5.0     NaN        NaN
# 4  45642.0     NaN        NaN
#
# [5 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2174 entries, 0 to 2173
# Data columns (total 25 columns):
# Red/Black                         0 non-null float64
# Carfax Has
# Report                 326 non-null object
# Carfax Has
# Manufacturer
# Recall    17 non-null object
# Carfax Has
# Warnings               36 non-null object
# Carfax Has
# Problems               36 non-null object
# Photos                            120 non-null float64
# Year                              2174 non-null int64
# Vehicle                           2174 non-null object
# VIN                               2174 non-null object
# Class                             2171 non-null object
# Class_type                        2171 non-null object
# Certified                         582 non-null object
# Deleted Date                      2174 non-null datetime64[ns]
# Status                            0 non-null float64
# Recall Status                     267 non-null object
# Age                               2174 non-null int64
# Body                              2173 non-null object
# Color                             2068 non-null object
# Disp                              2174 non-null object
# Price                             1879 non-null float64
# Book                              1536 non-null float64
# Cost                              2009 non-null float64
# Odometer                          2136 non-null float64
# Overall                           1385 non-null float64
# Like Mine                         1275 non-null float64
# dtypes: datetime64[ns](1), float64(9), int64(2), object(13)
# memory usage: 424.7+ KB

# %% [markdown]
# As we can see, there are quite a number of missing values in the dataset

# %%
# Visualization of null values
g = data.isnull().sum().sort_values(ascending=False)/len(data)*100
plt.figure(figsize=(15, 9))
g.plot(kind='bar')

# %%
# Lets look at some stats on the dataset
data.describe()
# Out:
#        Red/Black      Photos         Year  Status          Age          Price  \
# count        0.0  120.000000  2174.000000     0.0  2174.000000    1879.000000
# mean         NaN   37.741667  2015.756670     NaN    44.999540   47652.657265
# std          NaN    1.803339     3.463057     NaN    48.331703   21481.115158
# min          NaN   33.000000  1992.000000     NaN     1.000000    1302.000000
# 25%          NaN   37.000000  2015.000000     NaN    13.000000   32829.000000
# 50%          NaN   38.000000  2017.000000     NaN    30.000000   44995.000000
# 75%          NaN   39.000000  2018.000000     NaN    60.000000   57603.000000
# max          NaN   42.000000  2019.000000     NaN   503.000000  203000.000000
#
#                 Book           Cost       Odometer      Overall    Like Mine
# count    1536.000000    2009.000000    2136.000000  1385.000000  1275.000000
# mean    29401.794271   41691.962668   25193.669944    75.168231    75.105882
# std     17054.939781   23689.764625   37088.196311    30.386715    44.660614
# min       332.000000    -775.000000       3.000000    16.000000    16.000000
# 25%     19020.500000   27620.000000      13.000000    55.000000    47.000000
# 50%     28055.000000   42340.000000    6767.500000    70.000000    65.000000
# 75%     38835.000000   54578.000000   36021.750000    87.000000    90.000000
# max    118469.000000  205250.000000  263738.000000   330.000000   653.000000

# %% [markdown]
# About 9 columns are missing aroung 50% of their values. Some of the columns have features that allow the dealership manage their inventory against other dealerships in the area and therefore is not correlated with pricing the vehicle.

# %%
# Sales according to Model Year
data['Year'].value_counts().head(25).sort_values().plot(kind='barh', figsize=(15, 9))
plt.title('Sales according to Model Year')
plt.ylabel('Model Year')
plt.xlabel('Sold vehicle')
plt.show()

# %%
data['Age'].describe()
# Out:
# count    2174.000000
# mean       44.999540
# std        48.331703
# min         1.000000
# 25%        13.000000
# 50%        30.000000
# 75%        60.000000
# max       503.000000
# Name: Age, dtype: float64

# %%
data['Age'].value_counts().head(30).sort_values().plot(kind='barh', figsize=(15, 9))
plt.title('Sales according to Days in inventory')
plt.ylabel('Days in inventory')
plt.xlabel('Sold vehicle')
plt.show()

# %%
data['Color'].describe()
# Out:
# count      2068
# unique      226
# top       Black
# freq        549
# Name: Color, dtype: object

# %%
data['Color'].value_counts().head(40).sort_values().plot(kind='barh', figsize=(15, 9))
plt.title('Sales according to Vehicle Color')
plt.ylabel('Vehicle Color')
plt.xlabel('Sold vehicle')
plt.show()

# %%
data['Class'].describe()
# Out:
# count     2171
# unique       4
# top        SUV
# freq      1111
# Name: Class, dtype: object

# %%
data['Class'].value_counts().head(40).sort_values().plot(kind='bar', figsize=(15, 9))
plt.title('Sales according to Vehicle Class')
plt.ylabel('Vehicle Class')
plt.xlabel('Sold vehicle')
plt.show()

# %%
data['Class_type'].describe()
# Out:
# count                      2171
# unique                       16
# top        Luxury Sport Utility
# freq                        661
# Name: Class_type, dtype: object

# %%
plt.figure(figsize=(15, 9))
plt.title('Sales according to Vehicle Class', fontsize=12)
plt.xticks(rotation=90)
sns.countplot(data['Class_type'], order = data['Class_type'].value_counts().index);

# %%
plt.figure(figsize=(15, 9))
plt.plot(data.groupby('Year').size(), color='blue')

plt.title('Sales according to Vehicle Year')
plt.ylabel('Number of Vehicles Sold')
plt.xlabel('Vehicle Year')
plt.show()

# %% [markdown]
# #### Below is a visualization of the distribution of Car Price by their Model Year.

# %%
plt.figure(figsize=(15, 9))
# plot two values price per year_model
plt.scatter(data.Price, data.Year)
plt.xlabel("Price", fontsize=14)
plt.ylabel("Model Year", fontsize=14)
plt.title("Scatter plot of Price and Model year",fontsize=20)
plt.show()

# %% [markdown]
# #### Looking to express the Cars Price according to Class Type

# %%
f, ax = plt.subplots(figsize=(15, 9))
sns.stripplot(data = data, x='Price', y='Class_type', jitter=.1)
plt.show()

# %% [markdown]
# #### Price Distribution by Class

# %%
f, ax = plt.subplots(figsize=(15, 9))
sns.stripplot(data = data, x='Class', y='Price', jitter=.5)
plt.show()

# %%
plt.figure(figsize=(15,9))
data1 = data.drop('Price',1)
corrmat = data1.corr()
print(corrmat)

sns.heatmap(corrmat, cmap='coolwarm', annot=True)
# Out:
#            Red/Black    Photos      Year  Status       Age      Book  \
# Red/Black        NaN       NaN       NaN     NaN       NaN       NaN
# Photos           NaN  1.000000  0.018277     NaN -0.020559  0.218191
# Year             NaN  0.018277  1.000000     NaN  0.269829  0.665608
# Status           NaN       NaN       NaN     NaN       NaN       NaN
# Age              NaN -0.020559  0.269829     NaN  1.000000  0.242258
# Book             NaN  0.218191  0.665608     NaN  0.242258  1.000000
# Cost             NaN  0.155578  0.638435     NaN  0.269883  0.930384
# Odometer         NaN  0.063982 -0.870521     NaN -0.281560 -0.652153
# Overall          NaN  0.013137  0.270855     NaN  0.064688  0.149507
# Like Mine        NaN  0.109296  0.185543     NaN  0.048154  0.072955
#
#                Cost  Odometer   Overall  Like Mine
# Red/Black       NaN       NaN       NaN        NaN
# Photos     0.155578  0.063982  0.013137   0.109296
# Year       0.638435 -0.870521  0.270855   0.185543
# Status          NaN       NaN       NaN        NaN
# Age        0.269883 -0.281560  0.064688   0.048154
# Book       0.930384 -0.652153  0.149507   0.072955
# Cost       1.000000 -0.633039  0.256097   0.206995
# Odometer  -0.633039  1.000000 -0.235013  -0.166455
# Overall    0.256097 -0.235013  1.000000   0.737439
# Like Mine  0.206995 -0.166455  0.737439   1.000000

# %% [markdown]
#  It is important to understand possible correlations in your data, especially when building a regression model. Strongly correlated predictors, phenomenon referred to as multicollinearity, will cause coefficient estimates to be less reliable.
#  As we see above, Cost and book are highly correlated, as well as Overall and Like Mine. There are  no values for Status and Red/Black.

# %%
# Lets do some Feature engineering by dropping columns that do not have any impact towards vehicle pricing.
# Often, it is better to train your model with only significant features than to train it with all the features, 
# including unnecessary ones.

columns_to_drop = ['Red/Black', 'Deleted Date', 'Status', 'VIN', 'Recall Status','Disp', 'Book', 'Overall', 'Like Mine', 'Photos']
data.drop(labels=columns_to_drop, axis=1, inplace=True)
data.head()
# Out:
#   Carfax Has\nReport Carfax Has\nManufacturer\nRecall Carfax Has\nWarnings  \
# 0                NaN                              NaN                  NaN
# 1                Yes                              NaN                  NaN
# 2                NaN                              NaN                  NaN
# 3                NaN                              NaN                  NaN
# 4                NaN                              NaN                  NaN
#
#   Carfax Has\nProblems  Year                               Vehicle Class  \
# 0                  NaN  2018         Mercedes-Benz GLS 450 4MATIC®   SUV
# 1                  NaN  2015   Mercedes-Benz C-Class C 300 4MATIC®   Car
# 2                  NaN  2018   Mercedes-Benz S-Class S 450 4MATIC®   Car
# 3                  NaN  2017           Mercedes-Benz Sprinter 3500   Van
# 4                  NaN  2014  Mercedes-Benz M-Class ML 350 4MATIC®   SUV
#
#                     Class_type Certified  Age              Body  \
# 0         Luxury Sport Utility       NaN    1  4D Sport Utility
# 1                 Intermediate       Yes    1          4D Sedan
# 2                  Luxury High       NaN    1          4D Sedan
# 3               Full Size Vans       NaN    1      3D Cargo Van
# 4   Intermediate Sport Utility       NaN    1  4D Sport Utility
#
#             Color     Price     Cost  Odometer
# 0  Obsidian Black   76164.0  76514.0      45.0
# 1     Polar White       NaN      NaN   47525.0
# 2   Gray Metallic  116148.0      NaN      42.0
# 3    Arctic White   49526.0      NaN       5.0
# 4           Brown   25117.0      NaN   45642.0

# %%
# Now lets drop missing values for these important features since they missing values can not be assumed

data = data.dropna(subset=['Price','Odometer','Color','Cost']) #Drop null values
data.describe()
# Out:
#               Year          Age          Price           Cost       Odometer
# count  1720.000000  1720.000000    1720.000000    1720.000000    1720.000000
# mean   2016.602326    50.830233   46832.894767   45905.759302   15312.886628
# std       2.054520    44.024799   20789.211542   21044.399419   20456.400584
# min    2001.000000     1.000000    1302.000000    -775.000000       3.000000
# 25%    2015.000000    19.000000   31999.000000   32006.750000      12.000000
# 50%    2017.000000    40.000000   44548.000000   45269.000000    4454.500000
# 75%    2018.000000    67.000000   56801.000000   56499.500000   28263.750000
# max    2019.000000   310.000000  203000.000000  205250.000000  132218.000000

# %% [markdown]
# Lets visualize pairwise relationships in the dataset. It creates a matrix of axes and shows the realtionship for each pair of columns in our dataset. This also allows us to note outliers.

# %%
sns.pairplot(data);

# %% [markdown]
# From the visualization, you can see there is no evidence of extreme outliers.
# You can see the vehicles with the highest price have lower odometer readings and are the newer model year vehicles.

# %%
plt.figure(figsize=(15, 9))
sns.distplot(data['Price'])
plt.title("Plot of Prices Distribution",fontsize=20)
# Out:
# C:\Users\femis\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Plot of Prices Distribution')

# %%
# Lets turn the categorical features into numeric fields
data = pd.get_dummies(data)
data.head()
# Out:
#     Year  Age    Price     Cost  Odometer  Carfax Has\nReport_Yes  \
# 0   2018    1  76164.0  76514.0      45.0                       0
# 28  2018    2  62479.0  63004.0      41.0                       0
# 31  2018    2  50347.0  50697.0      35.0                       0
# 33  2018    2  77897.0  78247.0       9.0                       0
# 38  2018    2  25510.0  25860.0      15.0                       0
#
#     Carfax Has\nManufacturer\nRecall_Yes  Carfax Has\nWarnings_Yes  \
# 0                                      0                         0
# 28                                     0                         0
# 31                                     0                         0
# 33                                     0                         0
# 38                                     0                         0
#
#     Carfax Has\nProblems_Yes  Vehicle_Acura MDX 3.5L SH-AWD w/Advance Package  \
# 0                          0                                                0
# 28                         0                                                0
# 31                         0                                                0
# 33                         0                                                0
# 38                         0                                                0
#
#                  ...                 \
# 0                ...
# 28               ...
# 31               ...
# 33               ...
# 38               ...
#
#     Color_designo Magno Alanite Gray (Matte Finish)  \
# 0                                                 0
# 28                                                0
# 31                                                0
# 33                                                0
# 38                                                0
#
#     Color_designo Magno Night Black  \
# 0                                 0
# 28                                0
# 31                                0
# 33                                0
# 38                                0
#
#     Color_designo Magno Platinum (Matte Finish)  \
# 0                                             0
# 28                                            0
# 31                                            0
# 33                                            0
# 38                                            0
#
#     Color_designo Magno Selenite Gray  Color_designo Mocha Black  \
# 0                                   0                          0
# 28                                  0                          0
# 31                                  0                          0
# 33                                  0                          0
# 38                                  0                          0
#
#     Color_designo Mocha Black Metallic  Color_designo Mountain Gray Magno  \
# 0                                    0                                  0
# 28                                   0                                  0
# 31                                   0                                  0
# 33                                   0                                  0
# 38                                   0                                  0
#
#     Color_designo Mystic White Metallic  Color_designo Selenite Gray  \
# 0                                     0                            0
# 28                                    0                            0
# 31                                    0                            0
# 33                                    0                            0
# 38                                    0                            0
#
#     Color_designo Shadow Gray Magno
# 0                                 0
# 28                                0
# 31                                0
# 33                                0
# 38                                0
#
# [5 rows x 483 columns]

# %%
data.describe()
# Out:
#               Year          Age          Price           Cost       Odometer  \
# count  1720.000000  1720.000000    1720.000000    1720.000000    1720.000000
# mean   2016.602326    50.830233   46832.894767   45905.759302   15312.886628
# std       2.054520    44.024799   20789.211542   21044.399419   20456.400584
# min    2001.000000     1.000000    1302.000000    -775.000000       3.000000
# 25%    2015.000000    19.000000   31999.000000   32006.750000      12.000000
# 50%    2017.000000    40.000000   44548.000000   45269.000000    4454.500000
# 75%    2018.000000    67.000000   56801.000000   56499.500000   28263.750000
# max    2019.000000   310.000000  203000.000000  205250.000000  132218.000000
#
#        Carfax Has\nReport_Yes  Carfax Has\nManufacturer\nRecall_Yes  \
# count             1720.000000                           1720.000000
# mean                 0.156395                              0.004070
# std                  0.363335                              0.063683
# min                  0.000000                              0.000000
# 25%                  0.000000                              0.000000
# 50%                  0.000000                              0.000000
# 75%                  0.000000                              0.000000
# max                  1.000000                              1.000000
#
#        Carfax Has\nWarnings_Yes  Carfax Has\nProblems_Yes  \
# count               1720.000000               1720.000000
# mean                   0.008721                  0.008721
# std                    0.093005                  0.093005
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    0.000000                  0.000000
# max                    1.000000                  1.000000
#
#        Vehicle_Acura MDX 3.5L SH-AWD w/Advance Package  \
# count                                      1720.000000
# mean                                          0.000581
# std                                           0.024112
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                           1.000000
#
#                     ...                 \
# count               ...
# mean                ...
# std                 ...
# min                 ...
# 25%                 ...
# 50%                 ...
# 75%                 ...
# max                 ...
#
#        Color_designo Magno Alanite Gray (Matte Finish)  \
# count                                      1720.000000
# mean                                          0.001163
# std                                           0.034090
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                           1.000000
#
#        Color_designo Magno Night Black  \
# count                      1720.000000
# mean                          0.000581
# std                           0.024112
# min                           0.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           0.000000
# max                           1.000000
#
#        Color_designo Magno Platinum (Matte Finish)  \
# count                                  1720.000000
# mean                                      0.000581
# std                                       0.024112
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        Color_designo Magno Selenite Gray  Color_designo Mocha Black  \
# count                        1720.000000                1720.000000
# mean                            0.000581                   0.000581
# std                             0.024112                   0.024112
# min                             0.000000                   0.000000
# 25%                             0.000000                   0.000000
# 50%                             0.000000                   0.000000
# 75%                             0.000000                   0.000000
# max                             1.000000                   1.000000
#
#        Color_designo Mocha Black Metallic  Color_designo Mountain Gray Magno  \
# count                         1720.000000                        1720.000000
# mean                             0.000581                           0.000581
# std                              0.024112                           0.024112
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.000000
# 75%                              0.000000                           0.000000
# max                              1.000000                           1.000000
#
#        Color_designo Mystic White Metallic  Color_designo Selenite Gray  \
# count                          1720.000000                  1720.000000
# mean                              0.000581                     0.000581
# std                               0.024112                     0.024112
# min                               0.000000                     0.000000
# 25%                               0.000000                     0.000000
# 50%                               0.000000                     0.000000
# 75%                               0.000000                     0.000000
# max                               1.000000                     1.000000
#
#        Color_designo Shadow Gray Magno
# count                      1720.000000
# mean                          0.000581
# std                           0.024112
# min                           0.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           0.000000
# max                           1.000000
#
# [8 rows x 483 columns]

# %% [markdown]
# ## Splitting the Data

# %%
#Create a new column that for each row, generates a random number between 0 and 1, and
#if that value is less than or equal to .75, then sets the value of that cell as True
#and false otherwise. This is a quick and dirty way of randomly assigning some rows to
#be used as the training data and some as the test data.

data['is_train'] = np.random.uniform(0, 1, len(data)) <= .75

#Create two new dataframes, one with the training rows, one with the test rows

train, test = data[data['is_train']==True], data[data['is_train']==False]

#Show the number of observations for the test and training dataframes
print('Number of observations in the training data:', len(train))
print('Number of observations in the test data:',len(test))
# Out:
# Number of observations in the training data: 1291
# Number of observations in the test data: 429

# %% [markdown]
# #### Target Variable Analysis: Is it Normal?

# %%
#histogram and normal probability plot to view the Target variable = Price
from scipy.stats import norm

sns.distplot(train['Price'],fit=norm);
fig = plt.figure()
res = stats.probplot(train['Price'], plot=plt)
# Out:
# C:\Users\femis\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# The variable is certainly not normal: Let's apply a log transform on the data and see what happens...

# %%
train['Price'] = np.log(train['Price'])
sns.distplot(train['Price'],fit=norm);
fig = plt.figure()
res = stats.probplot(train['Price'], plot=plt)
# Out:
# C:\Users\femis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# The variable looks much better now.
#
# Normalizing the features will hopefully improve the regressions. We just have to remember to transform the output data back using an exponentiation at the end of the model.

# %% [markdown]
# ## A Random Tree Regressor
#
# To start off, let's try to train a simple model with a few of the features. Those features are:
#
# Year, Age and Odometer
#
# We will go for a very simple decision tree regression first. We can test for performance and overfitting using k-fold validation; here we take  k=10 . First, we take the data and make it useful...

# %%
from sklearn.tree import DecisionTreeRegressor as dtr
# define the training data X...

X = train[['Year','Age','Cost','Odometer']]
Y = train[['Price']]

# and the data for the competition submission...
X_test = test[['Year','Age','Cost','Odometer']]
print(X.head())
print(Y.head())
# Out:
#     Year  Age      Cost  Odometer
# 28  2018    2   63004.0      41.0
# 31  2018    2   50697.0      35.0
# 33  2018    2   78247.0       9.0
# 38  2018    2   25860.0      15.0
# 50  2019    2  121714.0      14.0
#         Price
# 28  11.042586
# 31  10.826694
# 33  11.263143
# 38  10.146826
# 50  11.010514

# %% [markdown]
# Now lets use cross validation to see how well a proposed regression model performs.

# %% [markdown]
# ### Explained Variance

# %%
# let's set up some cross-validation analysis to evaluate our model and later models...

from sklearn.model_selection import cross_val_score

# try fitting a decision tree regression model...
 # declare the regression model form. Let the depth be default.
DTR_1 = dtr(max_depth=None)

# fit the training data
scores_dtr = cross_val_score(DTR_1, X, Y, cv=10,scoring='explained_variance') # 10-fold cross validation
print('scores for k=10 fold validation:',scores_dtr)
print("Est. explained variance: %0.2f (+/- %0.2f)" % (scores_dtr.mean(), scores_dtr.std() * 2))
# Out:
# scores for k=10 fold validation: [0.85836235 0.94448394 0.85358973 0.9232396  0.97725728 0.96339979
#  0.97111944 0.42722106 0.96733851 0.97630087]
# Est. explained variance: 0.89 (+/- 0.32)

# %% [markdown]
# For explained variance, the best possible result is 1. Values below 1 indicate error in the regression.
#
# Let's use a random forest regressor instead. We will consider forests with varying numbers of trees (estimators), each of which provides a weak regression solution that can be averaged to get the overall regression output.

# %%
from sklearn.ensemble import RandomForestRegressor as rfr
estimators = [2, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]
mean_rfrs = []
std_rfrs_upper = []
std_rfrs_lower = []
yt = [i for i in Y['Price']] # quick pre-processing of the target
np.random.seed(11111)
for i in estimators:
    model = rfr(n_estimators=i,max_depth=None)
    scores_rfr = cross_val_score(model,X,yt,cv=10,scoring='explained_variance')
    print('estimators:',i)
    
# print('explained variance scores for k=10 fold validation:',scores_rfr)
    print("Est. explained variance: %0.2f (+/- %0.2f)" % (scores_rfr.mean(), scores_rfr.std() * 2))
    print('')
    mean_rfrs.append(scores_rfr.mean())
    std_rfrs_upper.append(scores_rfr.mean()+scores_rfr.std()*2) # for error plotting
    std_rfrs_lower.append(scores_rfr.mean()-scores_rfr.std()*2) # for error plotting
# Out:
# estimators: 2
# Est. explained variance: 0.85 (+/- 0.32)
#
# estimators: 5
# Est. explained variance: 0.88 (+/- 0.31)
#
# estimators: 10
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 15
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 20
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 25
# Est. explained variance: 0.89 (+/- 0.31)
#
# estimators: 30
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 35
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 40
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 45
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 50
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 55
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 60
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 65
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 70
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 75
# Est. explained variance: 0.90 (+/- 0.31)
#
# estimators: 80
# Est. explained variance: 0.90 (+/- 0.31)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax.plot(estimators,mean_rfrs,marker='o',
       linewidth=4,markersize=12)
ax.fill_between(estimators,std_rfrs_lower,std_rfrs_upper,
                facecolor='green',alpha=0.3,interpolate=True)
ax.set_ylim([-.3,1])
ax.set_xlim([0,80])
plt.title('Expected Variance of Random Forest Regressor')
plt.ylabel('Expected Variance')
plt.xlabel('Trees in Forest')
plt.grid()
plt.show()

# %% [markdown]
# The results are acceptable.
#
# Lets try using more features if there would be a difference.

# %% [markdown]
# ## Feature Ranking
#
# A mutual information regression for feature ranking and selection will be used. This metric measures the dependence between two random variables, in this case each feature in the data set and the Price regression target.
#
# Note that this doesn't consider combinations of feature values

# %%
included_features = [col for col in list(train)
                    if len([i for i in train[col].T.notnull() if i == True])==1291
                    and col!='Price']

X = train[included_features] # the feature data
Y = train[['Price']] # the target
yt = [i for i in Y['Price']] # the target list 
# and the data for the test...
X_test = test[included_features]

X.head()
# Out:
#     Year  Age      Cost  Odometer  Carfax Has\nReport_Yes  \
# 28  2018    2   63004.0      41.0                       0
# 31  2018    2   50697.0      35.0                       0
# 33  2018    2   78247.0       9.0                       0
# 38  2018    2   25860.0      15.0                       0
# 50  2019    2  121714.0      14.0                       0
#
#     Carfax Has\nManufacturer\nRecall_Yes  Carfax Has\nWarnings_Yes  \
# 28                                     0                         0
# 31                                     0                         0
# 33                                     0                         0
# 38                                     0                         0
# 50                                     0                         0
#
#     Carfax Has\nProblems_Yes  Vehicle_Acura MDX 3.5L SH-AWD w/Advance Package  \
# 28                         0                                                0
# 31                         0                                                0
# 33                         0                                                0
# 38                         0                                                0
# 50                         0                                                0
#
#     Vehicle_Acura MDX 3.5L w/Technology & Entertainment Pkgs    ...     \
# 28                                                  0           ...
# 31                                                  0           ...
# 33                                                  0           ...
# 38                                                  0           ...
# 50                                                  0           ...
#
#     Color_designo Magno Night Black  \
# 28                                0
# 31                                0
# 33                                0
# 38                                0
# 50                                0
#
#     Color_designo Magno Platinum (Matte Finish)  \
# 28                                            0
# 31                                            0
# 33                                            0
# 38                                            0
# 50                                            0
#
#     Color_designo Magno Selenite Gray  Color_designo Mocha Black  \
# 28                                  0                          0
# 31                                  0                          0
# 33                                  0                          0
# 38                                  0                          0
# 50                                  0                          0
#
#     Color_designo Mocha Black Metallic  Color_designo Mountain Gray Magno  \
# 28                                   0                                  0
# 31                                   0                                  0
# 33                                   0                                  0
# 38                                   0                                  0
# 50                                   0                                  0
#
#     Color_designo Mystic White Metallic  Color_designo Selenite Gray  \
# 28                                    0                            0
# 31                                    0                            0
# 33                                    0                            0
# 38                                    0                            0
# 50                                    0                            0
#
#     Color_designo Shadow Gray Magno  is_train
# 28                                0      True
# 31                                0      True
# 33                                0      True
# 38                                0      True
# 50                                0      True
#
# [5 rows x 483 columns]

# %% [markdown]
# ##### Mutual Information Regression Metric for Feature Ranking
#
# We will use mutual information regression for feature ranking and selection. This metric measures the dependence between two random variables, in this case each feature in the data set and the Price regression target.

# %%
import sklearn.feature_selection as fs

mir_result = fs.mutual_info_regression(X, yt) # mutual information regression feature ordering
feature_scores = []
for i in np.arange(len(included_features)):
    feature_scores.append([included_features[i],mir_result[i]])
sorted_scores = sorted(np.array(feature_scores), key=lambda s: float(s[1]), reverse=True) 
print(np.array(sorted_scores))
# Out:
# [['Cost' '2.458684485988147']
#  ['Year' '0.4312238390703369']
#  ['Odometer' '0.429507403845498']
#  ['Vehicle_Mercedes-Benz GLC 300 4MATIC®' '0.21488997309418534']
#  ['Class_type_ Luxury Sport Utility' '0.1363447412381269']
#  ['Certified_Yes' '0.12821585616690112']
#  ['Vehicle_Mercedes-Benz GLE 350 4MATIC®' '0.11985633167946186']
#  ['Age' '0.11529424430423241']
#  ['Vehicle_Mercedes-Benz GLS 450 4MATIC®' '0.1083454686989721']
#  ['Class_type_ Full Size Vans' '0.09185576033469789']
#  ['Class_Van' '0.09121135565094596']
#  ['Vehicle_Mercedes-Benz E-Class E 300 4MATIC®' '0.07818711572633763']
#  ['Body_3D Cargo Van' '0.07418301840031583']
#  ['Vehicle_Mercedes-Benz GLA 250 4MATIC®' '0.0735939987919445']
#  ['Body_4D Sport Utility' '0.07218053373515909']
#  ['Class_SUV' '0.07216122469369468']
#  ['Class_type_ Intermediate Sport Utility' '0.0716133008238411']
#  ['Class_Car' '0.06438917620678675']
#  ['Class_type_ Luxury High' '0.06056811034233833']
#  ['Vehicle_Mercedes-Benz C-Class C 300 4MATIC®' '0.05170283710452517']
#  ['Class_type_ Intermediate' '0.04751153308386691']
#  ['Body_4D Sedan' '0.04714753162975582']
#  ['Class_type_ Compact' '0.043515555681065576']
#  ['Vehicle_Mercedes-Benz CLA 250 4MATIC®' '0.04061231166963264']
#  ['Vehicle_Mercedes-Benz M-Class ML 350 4MATIC®' '0.03818169866505383']
#  ['Vehicle_Mercedes-Benz Metris Cargo' '0.03801468739320035']
#  ['Carfax Has\nReport_Yes' '0.037040326629585785']
#  ['Vehicle_Mercedes-Benz S-Class S 550 4MATIC®' '0.03423837995263279']
#  ['Color_Polar White' '0.03168917933142157']
#  ['Vehicle_Mercedes-Benz GLK 350 4MATIC®' '0.026994204516427533']
#  ['Vehicle_Mercedes-Benz GLS 550 4MATIC®' '0.026399741882807137']
#  ['Vehicle_Mercedes-Benz S-Class S 560 4MATIC®' '0.02590796506275994']
#  ['Class_type_ Compact Sport Utility' '0.024431580579725054']
#  ['Color_Artic White' '0.02428828785880488']
#  ['Vehicle_Mercedes-Benz E-Class E 350 4MATIC®' '0.02386788973034326']
#  ['Vehicle_Mercedes-Benz GL-Class GL 450 4MATIC®' '0.023459660778694214']
#  ['Color_Mountain Gray Metallic' '0.022792613852690047']
#  ['Vehicle_Mercedes-Benz Sprinter 2500 Cargo 144 WB'
#   '0.02206757950157401']
#  ['Vehicle_Mercedes-Benz GLE 43 AMG® Coupe 4MATIC®'
#   '0.019511046380951802']
#  ['Color_Cirrus White' '0.018877838064421115']
#  ['Vehicle_Mercedes-Benz E-Class E 400 4MATIC®' '0.018698646303642263']
#  ['Vehicle_Mercedes-Benz Sprinter 3500 Cargo 144 WB'
#   '0.018452374851813613']
#  ['Vehicle_Mercedes-Benz Sprinter 2500 Cargo 170 WB High Roof'
#   '0.018416243131958554']
#  ['Color_Jupiter Red' '0.01802511747463098']
#  ['Vehicle_Mercedes-Benz GLE 43 AMG® 4MATIC®' '0.017538518653705593']
#  ['Color_Black' '0.016120559482683428']
#  ['Color_Arctic White' '0.016003578095168836']
#  ['Vehicle_Mercedes-Benz S-Class S 450 4MATIC®' '0.015688725719457786']
#  ['Vehicle_Mercedes-Benz Metris Passenger' '0.015001747645762564']
#  ['Body_4D Passenger Van' '0.014057114725608444']
#  ['Color_Palladium Silver Metallic' '0.012330880744723549']
#  ['Vehicle_Mercedes-Benz GL-Class GL 550 4MATIC®' '0.012300060725607742']
#  ['Class_type_ Luxury' '0.012020578288783446']
#  ['Body_2D Convertible' '0.0115384419540141']
#  ['Vehicle_Mercedes-Benz E-Class E 43 AMG® 4MATIC®'
#   '0.010919692209069298']
#  ['Color_Night Black' '0.010641168527505851']
#  ['Vehicle_Mercedes-Benz S-Class S 63 AMG® 4MATIC®'
#   '0.010498519870553391']
#  ['Color_Diamond White' '0.0104664219624645']
#  ['Color_Cardinal Red Metallic' '0.009636158286635443']
#  ['Color_Iridium Silver Metallic' '0.008271773390359671']
#  ['Color_Lunar' '0.007946515692525802']
#  ['Vehicle_Mercedes-Benz C-Class C 300 Sport 4MATIC®'
#   '0.007725773428735372']
#  ['Vehicle_Mercedes-Benz Sprinter 2500' '0.007654757219947239']
#  ['Color_designo Diamond White Metallic' '0.007209111495428244']
#  ['Color_Brilliant Silver' '0.007103171079384962']
#  ['Color_Grey' '0.006944771960770479']
#  ['Color_Gray' '0.006803964938904672']
#  ['Color_Steel Gray Metallic' '0.006656485252108046']
#  ['Color_Chrome' '0.006510262958422941']
#  ['Color_White' '0.006463741246214738']
#  ['Body_2D Coupe' '0.006388868503466316']
#  ['Body_3D Extended Cargo Van' '0.006300491130242003']
#  ['Color_Selenite Gray Metallic' '0.0056832443154331']
#  ['Vehicle_Mercedes-Benz C-Class C 400 4MATIC®' '0.004898871963544327']
#  ['Color_Cardinal Red' '0.004494911294087189']
#  ['Color_Jet Black' '0.004421004403084572']
#  ['Vehicle_Jeep Grand Cherokee Limited' '0.004293322214465545']
#  ['Class_Truck' '0.004212975213610748']
#  ['Color_Obsidian Black Metallic' '0.004032564723931986']
#  ['Vehicle_Mercedes-Benz Sprinter 3500 Cargo 170 WB'
#   '0.0036297079477195515']
#  ['Vehicle_Mercedes-Benz C-Class C 43 AMG® 4MATIC®'
#   '0.0035080233272056782']
#  ['Color_Blue Metallic' '0.0033988658262703586']
#  ['Color_Alpine White' '0.0032289135485941145']
#  ['Body_Passenger Van' '0.0031003346826319333']
#  ['Class_type_ Luxury Sport' '0.003099967176492191']
#  ['Vehicle_Mercedes-Benz Metris' '0.0024658076927819295']
#  ['Color_Gray Metallic' '0.0022691213149431677']
#  ['Color_Obsidian Black' '0.0019232669400893743']
#  ['Color_Blue' '0.0013113502392408938']
#  ['Color_Anthracite Blue Metallic' '0.001141452591431058']
#  ['Body_4D SuperCrew' '0.0010333939100097833']
#  ['Color_Tuxedo Black Metallic' '0.0010321906580397222']
#  ['Color_Selenite Gray' '0.0010309892723050496']
#  ['Vehicle_Mercedes-Benz G-Class G 63 AMG® 4MATIC®'
#   '0.0009018903825555036']
#  ['Vehicle_BMW 7 Series ALPINA B7 xDrive' '0.0008882620682234554']
#  ['Vehicle_Mercedes-Benz E-Class E 550' '0.0008760313757669724']
#  ['Vehicle_Mercedes-Benz SL-Class SL 550' '0.0008733124131737879']
#  ['Color_Silver' '0.0008677892802979592']
#  ['Vehicle_Mercedes-Benz E-Class E 350 Base' '0.0007768808627865997']
#  ['Color_designo Mountain Gray Magno' '0.0007763975162534686']
#  ['Vehicle_Toyota Highlander SE' '0.0007757984581454602']
#  ['Vehicle_Mercedes-Benz GLA 45 AMG® 4MATIC®' '0.0007751942642834075']
#  ['Vehicle_Mercedes-Benz M-Class ML 63 AMG® 4MATIC®'
#   '0.0007745942708855535']
#  ['Vehicle_BMW 5 Series 528i xDrive' '0.0007745933384969428']
#  ['Vehicle_Ford F-150 STX' '0.0007745933384969428']
#  ['Vehicle_Mercedes-Benz Sprinter 2500 Passenger 144 WB BlueTEC®'
#   '0.0007745933384969428']
#  ['Color_Dark Graphite Metallic II' '0.0007745933384969428']
#  ['Body_4D Wagon' '0.0007739956800670855']
#  ['Vehicle_Mercedes-Benz GLE 450 4MATIC®' '0.0007739928785422956']
#  ['Vehicle_Mercedes-Benz Sprinter 3500 Cargo 170.3 in WB'
#   '0.0006448939887937488']
#  ['Class_type_ Large Pick-up' '0.0006312118887933371']
#  ['Body_4D Hatchback' '0.000623011240463045']
#  ['Vehicle_Mercedes-Benz CLS 550 4MATIC®' '0.0005429020790183037']
#  ['Color_Glacier White Metallic' '0.0005334002500245738']
#  ['Vehicle_Mercedes-Benz E-Class E 250 4MATIC®' '0.000525458766520881']
#  ['Vehicle_Tesla Model X 75D' '0.000525458766520881']
#  ['Color_Black Copper Pearl' '0.0005236376215624894']
#  ['Color_Vanda Blue' '0.0005224258992986286']
#  ['Vehicle_Mercedes-Benz M-Class ML 550 4MATIC®' '0.0005212160696115298']
#  ['Color_designo Magno Selenite Gray' '0.0005181997367542657']
#  ['Vehicle_Cadillac CTS Luxury' '0.0005175978771272405']
#  ['Vehicle_Audi A8 L 3.0T quattro' '0.0005169964847842046']
#  ['Vehicle_Audi A8 L 4.2 quattro' '0.0005169964847842046']
#  ['Vehicle_Chevrolet Volt LT' '0.0005169964847842046']
#  ['Color_Carbon Gray Metallic' '0.0005169964847842046']
#  ['Color_Dark Blue Metallic' '0.0005169964847842046']
#  ['Color_designo Magno Alanite Gray (Matte Finish)'
#   '0.0005169964847842046']
#  ['Vehicle_Mercedes-Benz SL-Class SL 400 Roadster'
#   '0.0005164006969398116']
#  ['Color_Platinum Gray Metallic' '0.0005163964913863506']
#  ['Color_Bright Silver' '0.0005163964913845742']
#  ['Vehicle_Acura MDX 3.5L SH-AWD w/Advance Package'
#   '0.0005163955589977398']
#  ['Vehicle_Honda Accord LX-S' '0.0005163955589977398']
#  ['Vehicle_INFINITI QX80 Base' '0.0005163955589977398']
#  ['Vehicle_Kia Soul Base' '0.0005163955589977398']
#  ['Vehicle_Lexus GX 460 Luxury' '0.0005163955589977398']
#  ['Vehicle_Mercedes-Benz AMG® GT R' '0.0005163955589977398']
#  ['Vehicle_Mercedes-Benz AMG® GT S' '0.0005163955589977398']
#  ['Vehicle_Mercedes-Benz SLK 300' '0.0005163955589977398']
#  ['Vehicle_Nissan Rogue SV' '0.0005163955589977398']
#  ['Vehicle_Porsche Cayenne GTS' '0.0005163955589977398']
#  ['Vehicle_Porsche Panamera 4S' '0.0005163955589977398']
#  ['Vehicle_Rolls-Royce Ghost Base' '0.0005163955589977398']
#  ['Body_4D Station Wagon' '0.0005163955589977398']
#  ['Color_Black Onyx' '0.0005163955589977398']
#  ['Color_Cayenne Red' '0.0005163955589977398']
#  ['Color_Deep Blue Metallic' '0.0005163955589977398']
#  ['Color_Hermosa Blue' '0.0005163955589977398']
#  ['Color_Ice Silver Metallic' '0.0005163955589977398']
#  ['Color_L3c' '0.0005163955589977398']
#  ['Color_Satin Steel Metallic' '0.0005163955589977398']
#  ['Color_designo Mystic White Metallic' '0.0005163955589977398']
#  ['Vehicle_Mercedes-Benz CLS 63 S AMG® 4MATIC®' '0.0005157950990430926']
#  ['Color_Red' '0.0005151955729338908']
#  ['Color_Graphite' '0.0005145937133068657']
#  ['Color_Cocoa Brown Metallic' '0.00038609668318423385']
#  ['Vehicle_Mercedes-Benz GLK 250 4MATIC®' '0.0003854948235574307']
#  ['Vehicle_Nissan NV2500 HD SV Standard Roof' '0.0003830774625641631']
#  ['Vehicle_Mercedes-Benz GLC 43 AMG® 4MATIC®' '0.0003209453786815475']
#  ['Class_type_ Sport' '0.0002952570906566976']
#  ['Vehicle_Land Rover Range Rover 5.0L V8 Supercharged Autobiography'
#   '0.00029510479821182045']
#  ['Color_Iridium Silver' '0.0002708887720481723']
#  ['Vehicle_Buick Regal CXL Oshawa' '0.0002660464147645758']
#  ['Vehicle_Honda Accord Sport' '0.0002660464147645758']
#  ['Vehicle_Ford Expedition Limited' '0.0002636229687547065']
#  ['Vehicle_Ford F-150 XLT' '0.00026181034710193174']
#  ['Vehicle_Mercedes-Benz GL-Class GL 350 BlueTEC®'
#   '0.00026181034710193174']
#  ['Vehicle_BMW 3 Series 328i xDrive' '0.0002600056955202046']
#  ['Color_Brilliant Blue' '0.0002600056955202046']
#  ['Vehicle_Mercedes-Benz E-Class E 550 4MATIC®' '0.0002600019572551737']
#  ['Color_Dolomite Brown Metallic' '0.0002600019572551737']
#  ['Color_Absolute Black Metallic' '0.0002600019572549517']
#  ['Vehicle_MINI Cooper S Countryman Base' '0.00025940289914738734']
#  ['Color_Smoky Granite Mica' '0.00025940009762814853']
#  ['Color_Cyber Gray Metallic' '0.0002594000976279265']
#  ['Vehicle_Audi Q5 2.0T Premium Plus quattro' '0.0002587987052851126']
#  ['Color_Gun Metallic' '0.0002587987052851126']
#  ['Color_Ingot' '0.0002587987052851126']
#  ['Color_Yulong White' '0.0002587987052851126']
#  ['Vehicle_Mercedes-Benz SL-Class SL 500 Base' '0.0002587987052848906']
#  ['Vehicle_Volkswagen Jetta SEL 2.5' '0.0002587987052848906']
#  ['Color_White Orchid Pearl' '0.0002587987052848906']
#  ['Vehicle_Honda CR-V EX' '0.00025819777949864786']
#  ['Vehicle_Jaguar XJ XJL Portfolio' '0.00025819777949864786']
#  ['Vehicle_Lexus SC 430' '0.00025819777949864786']
#  ['Vehicle_Nissan Rogue SL' '0.00025819777949864786']
#  ['Vehicle_Subaru Outback 3.6R Limited' '0.00025819777949864786']
#  ['Color_Blizzard Pearl' '0.00025819777949864786']
#  ['Color_Crystal White Pearl' '0.00025819777949864786']
#  ['Color_Glacier White' '0.00025819777949864786']
#  ['Color_Maximum Steel Metallic Clearcoat' '0.00025819777949864786']
#  ['Color_Oxford White' '0.00025819777949864786']
#  ['Color_South Seas Blue Metallic' '0.00025819777949864786']
#  ['Vehicle_BMW 6 Series 650i xDrive' '0.0002581977794984258']
#  ['Vehicle_Ford Mustang V6' '0.0002581977794984258']
#  ['Vehicle_Jeep Cherokee Limited' '0.0002581977794984258']
#  ['Vehicle_Land Rover Range Rover Sport 5.0L V8 Supercharged'
#   '0.0002581977794984258']
#  ['Vehicle_Volkswagen Jetta SportWagen 2.5L S' '0.0002581977794984258']
#  ['Vehicle_Volkswagen Passat 1.8T S' '0.0002581977794984258']
#  ['Color_Avalanche Gray' '0.0002581977794984258']
#  ['Color_Black Sapphire Metallic' '0.0002581977794984258']
#  ['Color_Fortana Red' '0.0002581977794984258']
#  ['Vehicle_Mercedes-Benz Sprinter 2500 Passenger 144 WB'
#   '0.0002575973195451109']
#  ['Color_040' '0.0002575973195442227']
#  ['Color_Bright White Clearcoat' '0.0002575973195442227']
#  ['Color_Magnetic Gray Metallic' '0.0002575973195442227']
#  ['Vehicle_BMW X3 xDrive28i' '0.0002563959338077737']
#  ['Vehicle_Mercedes-Benz E-Class E 400' '0.0002563959338077737']
#  ['Vehicle_Mercedes-Benz GLE 400 4MATIC®' '0.00025639593380755166']
#  ['Carfax Has\nWarnings_Yes' '0.00013787561327949227']
#  ['Carfax Has\nProblems_Yes' '0.00013787561327949227']
#  ['Color_Brilliant Blue Metallic' '0.00013331018748041767']
#  ['Carfax Has\nManufacturer\nRecall_Yes' '0.00010555790243327312']
#  ['Color_Stone Gray Metallic' '9.911436895315706e-05']
#  ['Color_Diamond White Metallic' '5.938980133346483e-05']
#  ['Vehicle_Mercedes-Benz GLE 550e 4MATIC®' '3.125760982636283e-05']
#  ['Class_type_ Chassis' '3.0608221512129496e-05']
#  ['Vehicle_Mercedes-Benz S-Class S 550' '2.8737222301455922e-05']
#  ['Vehicle_Audi Q7 3.0T Premium quattro' '2.2550728783543583e-05']
#  ['Color_Carbon Black Metallic' '2.196802781784246e-05']
#  ['Color_Monsoon Gray Metallic' '1.2739245521253828e-05']
#  ['Vehicle_Mercedes-Benz C-Class C 350 4MATIC®' '1.0888644264128722e-05']
#  ['Vehicle_Subaru Impreza 2.0i Limited' '1.088014719041741e-05']
#  ['Vehicle_Ford Explorer Limited' '1.0271668526518063e-05']
#  ['Vehicle_Mercedes-Benz Sprinter 3500 Passenger 170 Extended WB High Roof'
#   '1.0271668526518063e-05']
#  ['Color_Starfire Pearl' '9.671208574091317e-06']
#  ['Vehicle_MINI Cooper Base' '8.449095217355485e-06']
#  ['Vehicle_Honda Accord Touring' '7.842522519507789e-06']
#  ['Vehicle_Land Rover Range Rover Sport HSE' '6.647249522928611e-06']
#  ['Vehicle_Audi A8 L 3.0 TDI quattro' '6.630800253870639e-06']
#  ['Color_Polar Whiet' '6.630800253870639e-06']
#  ['Color_Ingot Silver Metallic' '6.030340300555714e-06']
#  ['Vehicle_Toyota Highlander XLE V6' '6.0256492072641166e-06']
#  ['Vehicle_Dodge Challenger SXT' '5.425189255725549e-06']
#  ['Color_White Diamond Pearl' '4.8205106134568965e-06']
#  ['Vehicle_Mercedes-Benz E-Class E 63 AMG® Base' '4.820510613234852e-06']
#  ['Vehicle_Ford F-350SD Platinum' '4.816763596093843e-06']
#  ['Body_2D Hatchback' '3.6125676029508114e-06']
#  ['Vehicle_Jeep Grand Cherokee Altitude' '3.0093017621135587e-06']
#  ['Vehicle_Mercedes-Benz C-Class C 300' '3.006965344387602e-06']
#  ['Vehicle_Mercedes-Benz Sprinter 3500 Cargo 170 WB High Roof'
#   '2.411181860950684e-06']
#  ['Body_4D Access Cab' '2.406505390184499e-06']
#  ['Vehicle_Mazda CX-9 Grand Touring' '2.4065053899624544e-06']
#  ['Vehicle_Honda Accord Crosstour EX-L' '2.404637708619539e-06']
#  ['Vehicle_Audi Q7 3.0 TDI Premium Plus quattro' '1.8027780833707041e-06']
#  ['Vehicle_Dodge Durango Citadel' '1.8027780833707041e-06']
#  ['Vehicle_Nissan Pathfinder Platinum' '1.2051196481843718e-06']
#  ['Vehicle_Toyota Tundra Platinum 5.7L V8' '1.202318129167601e-06']
#  ['Body_4D CrewMax' '1.202318129167601e-06']
#  ['Color_Victory Red' '1.202318129167601e-06']
#  ['Vehicle_Mercedes-Benz GLE 43C4 4MATIC®' '1.2013857394466143e-06']
#  ['Body_3D Passenger Van' '1.2013857394466143e-06']
#  ['Color_designo Selenite Gray' '1.2013857394466143e-06']
#  ['Vehicle_Mercedes-Benz E-Class E 63 S AMG® 4MATIC®'
#   '6.027920133044873e-07']
#  ['Vehicle_Jeep Grand Cherokee Overland' '6.009257861316897e-07']
#  ['Vehicle_Lexus ES 350' '6.009257861316897e-07']
#  ['Vehicle_MINI Cooper S Base' '6.009257861316897e-07']
#  ['Vehicle_Mercedes-Benz S-Class S 600' '6.009257861316897e-07']
#  ['Vehicle_Tesla Model S P85D' '6.009257861316897e-07']
#  ['Vehicle_Toyota Corolla XLE' '6.009257861316897e-07']
#  ['Vehicle_Toyota Prius Base' '6.009257861316897e-07']
#  ['Color_Black Metallic' '6.009257861316897e-07']
#  ['Color_Brown Metallic' '6.009257861316897e-07']
#  ['Color_designo Magno Platinum (Matte Finish)' '9.992007221626409e-16']
#  ['Color_designo Shadow Gray Magno' '9.992007221626409e-16']
#  ['is_train' '9.992007221626409e-16']
#  ['Vehicle_Acura MDX 3.5L w/Technology & Entertainment Pkgs' '0.0']
#  ['Vehicle_Acura MDX Technology' '0.0']
#  ['Vehicle_Acura TL 3.5 w/Technology Package' '0.0']
#  ['Vehicle_Audi A3 2.0T Premium Plus quattro' '0.0']
#  ['Vehicle_Audi A4 2.0T Premium Plus quattro' '0.0']
#  ['Vehicle_Audi A6 2.0T Premium Plus quattro' '0.0']
#  ['Vehicle_Audi Q5 3.2 Premium quattro' '0.0']
#  ['Vehicle_Audi RS 5 4.2 quattro' '0.0']
#  ['Vehicle_BMW 5 Series 550i xDrive' '0.0']
#  ['Vehicle_BMW 7 Series 750i xDrive' '0.0']
#  ['Vehicle_BMW X1 xDrive28i' '0.0']
#  ['Vehicle_BMW X5 M Base' '0.0']
#  ['Vehicle_Buick Enclave Leather Group' '0.0']
#  ['Vehicle_Cadillac Escalade ESV Luxury' '0.0']
#  ['Vehicle_Cadillac SRX Performance' '0.0']
#  ['Vehicle_Cadillac XTS Premium' '0.0']
#  ['Vehicle_Chevrolet Camaro 1LT' '0.0']
#  ['Vehicle_Chevrolet Corvette Base Hardtop' '0.0']
#  ['Vehicle_Chevrolet Express 1500 Work Van Cargo' '0.0']
#  ['Vehicle_Chevrolet SSR Base' '0.0']
#  ['Vehicle_Fiat 500L Lounge' '0.0']
#  ['Vehicle_Ford Escape Titanium' '0.0']
#  ['Vehicle_GMC Acadia Denali' '0.0']
#  ['Vehicle_GMC Yukon XL Denali' '0.0']
#  ['Vehicle_Honda CR-V LX' '0.0']
#  ['Vehicle_Honda Pilot Touring' '0.0']
#  ['Vehicle_Hyundai Tucson Limited' '0.0']
#  ['Vehicle_Hyundai Veloster Base w/Black' '0.0']
#  ['Vehicle_INFINITI EX35 Journey' '0.0']
#  ['Vehicle_INFINITI QX56 Base' '0.0']
#  ['Vehicle_INFINITI QX60 Base' '0.0']
#  ['Vehicle_Jeep Wrangler Unlimited Rubicon' '0.0']
#  ['Vehicle_Jeep Wrangler Unlimited Sahara' '0.0']
#  ['Vehicle_Kia Optima SXL Turbo' '0.0']
#  ['Vehicle_Kia Sportage LX' '0.0']
#  ['Vehicle_Land Rover LR4 HSE' '0.0']
#  ['Vehicle_Land Rover Range Rover 5.0L V8 Supercharged' '0.0']
#  ['Vehicle_Land Rover Range Rover Evoque Dynamic' '0.0']
#  ['Vehicle_Land Rover Range Rover Evoque SE' '0.0']
#  ['Vehicle_Land Rover Range Rover HSE' '0.0']
#  ['Vehicle_Lexus GS 350' '0.0']
#  ['Vehicle_Lexus LX 570' '0.0']
#  ['Vehicle_Lexus RX 350' '0.0']
#  ['Vehicle_Lincoln MKT EcoBoost' '0.0']
#  ['Vehicle_Mazda CX-3 Grand Touring' '0.0']
#  ['Vehicle_Mazda CX-5 Touring' '0.0']
#  ['Vehicle_Mercedes-Benz 2500 170 High Roof' '0.0']
#  ['Vehicle_Mercedes-Benz AMG® GT Base' '0.0']
#  ['Vehicle_Mercedes-Benz C-Class C 280 Luxury 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz C-Class C 350 Sport 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz C-Class C 350e' '0.0']
#  ['Vehicle_Mercedes-Benz C-Class C 450 AMG® 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz C-Class C 63 AMG®' '0.0']
#  ['Vehicle_Mercedes-Benz CL-Class CL 550 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz CLA 45 AMG® 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz CLK 350 Base' '0.0']
#  ['Vehicle_Mercedes-Benz CLS 400 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz E-Class E 450 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz E-Class E 53 AMG® 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz G-Class G 550 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz GL-Class GL 63 AMG® 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz GLC 300' '0.0']
#  ['Vehicle_Mercedes-Benz GLC 300 Coupe 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz GLE 300d 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz GLE 63 AMG® 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz GLE 63 S AMG® 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz GLE 63 S AMG® Coupe 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz GLS 63 AMG® 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz M-Class ML 250 BlueTEC®' '0.0']
#  ['Vehicle_Mercedes-Benz M-Class ML 400 4MATIC®' '0.0']
#  ['Vehicle_Mercedes-Benz S-Class S 63 AMG® Base' '0.0']
#  ['Vehicle_Mercedes-Benz S-Class S 65 AMG®' '0.0']
#  ['Vehicle_Mercedes-Benz SL-Class SL 400 Cabriolet' '0.0']
#  ['Vehicle_Mercedes-Benz SLC 43 AMG® Base' '0.0']
#  ['Vehicle_Mercedes-Benz SLK 350' '0.0']
#  ['Vehicle_Mercedes-Benz Sprinter 2500 BlueTEC®' '0.0']
#  ['Vehicle_Mercedes-Benz Sprinter 2500 Cargo 144 WB BlueTEC®' '0.0']
#  ['Vehicle_Mercedes-Benz Sprinter 2500 Cargo 170 WB Extended' '0.0']
#  ['Vehicle_Mercedes-Benz Sprinter 2500 Passenger 144 WB Passenger Van High Roof 144 WB RWD'
#   '0.0']
#  ['Vehicle_Mercedes-Benz Sprinter 2500 Passenger 170 WB High Roof' '0.0']
#  ['Vehicle_Mercedes-Benz Sprinter 2500 Worker Cargo 170 WB High Roof'
#   '0.0']
#  ['Vehicle_Nissan Altima 2.5 SL' '0.0']
#  ['Vehicle_Nissan Armada Platinum' '0.0']
#  ['Vehicle_Nissan Murano S' '0.0']
#  ['Vehicle_Porsche Cayenne S' '0.0']
#  ['Vehicle_Porsche Panamera 4' '0.0']
#  ['Vehicle_Ram 2500 Big Horn' '0.0']
#  ['Vehicle_Toyota Avalon Limited' '0.0']
#  ['Vehicle_Toyota Corolla LE' '0.0']
#  ['Vehicle_Toyota Sienna XLE' '0.0']
#  ['Vehicle_Toyota Tacoma Base V6' '0.0']
#  ['Vehicle_Volkswagen CC R-Line' '0.0']
#  ['Class_type_ Large Sport Utility' '0.0']
#  ['Class_type_ Small Pick-up' '0.0']
#  ['Class_type_ Small Van' '0.0']
#  ['Class_type_ Subcompact' '0.0']
#  ['Body_2D Standard Cab' '0.0']
#  ['Body_3D Hatchback' '0.0']
#  ['Body_4D Crew Cab' '0.0']
#  ['Color_149' '0.0']
#  ['Color_Atomic Silver' '0.0']
#  ['Color_Billet Silver Metallic Clearcoat' '0.0']
#  ['Color_Black Clearcoat' '0.0']
#  ['Color_Black Clearcoat/Black Hard Top' '0.0']
#  ['Color_Black Obsidian' '0.0']
#  ['Color_Black Raven' '0.0']
#  ['Color_Brilliant Black Crystal Pearlcoat' '0.0']
#  ['Color_Brilliant Silver Metallic' '0.0']
#  ['Color_Capri Blue Metallic' '0.0']
#  ['Color_Classic Silver Metallic' '0.0']
#  ['Color_Colima Lime' '0.0']
#  ['Color_Cosmic Blue Metallic' '0.0']
#  ['Color_Cosmos Black Metallic' '0.0']
#  ['Color_Crystal Red Tintcoat' '0.0']
#  ['Color_Cuprite Brown Metallic' '0.0']
#  ['Color_Dark Sapphire Blue Metallic' '0.0']
#  ['Color_Deep Black Metallic' '0.0']
#  ['Color_Deep Crystal Blue Mica' '0.0']
#  ['Color_Dolomite' '0.0']
#  ['Color_Ebony Black' '0.0']
#  ['Color_Eminent White Pearl' '0.0']
#  ['Color_F' '0.0']
#  ['Color_Fuji White' '0.0']
#  ['Color_Garnet Red Tintcoat' '0.0']
#  ['Color_Glacier Pearl' '0.0']
#  ['Color_Graphite Gray Metallic' '0.0']
#  ['Color_Graphite Luster Metallic' '0.0']
#  ['Color_Grigio Scuro (Gray Metallic)' '0.0']
#  ['Color_Ibis White' '0.0']
#  ['Color_Imperial Blue Metallic' '0.0']
#  ['Color_Liquid Platinum' '0.0']
#  ['Color_Lotus Gray Metallic/Black Roof' '0.0']
#  ['Color_Lunar Blue Metallic' '0.0']
#  ['Color_Magnetite Black Metallic' '0.0']
#  ['Color_Mars Red' '0.0']
#  ['Color_Mayan Bronze Metallic' '0.0']
#  ['Color_Meteor Gray Metallic' '0.0']
#  ['Color_Midnight Black Metallic' '0.0']
#  ['Color_Mineral Gray Metallic Clearcoat' '0.0']
#  ['Color_Modern Steel Metallic' '0.0']
#  ['Color_Mountain Crystal White Metallic' '0.0']
#  ['Color_Mythos Black Metallic' '0.0']
#  ['Color_Nautical Blue Metallic' '0.0']
#  ['Color_Nebula Gray Pearl' '0.0']
#  ['Color_Night Blue Metallic' '0.0']
#  ['Color_Obsidian' '0.0']
#  ['Color_Palladium Silver' '0.0']
#  ['Color_Panther Black Crystal Effect' '0.0']
#  ['Color_Pearl White' '0.0']
#  ['Color_Pebble' '0.0']
#  ['Color_Pebble Gray' '0.0']
#  ['Color_Polar Silver Metallic' '0.0']
#  ['Color_Rhino Clearcoat' '0.0']
#  ['Color_Ruby Black Metallic' '0.0']
#  ['Color_Ruby Red Tinted Clearcoat' '0.0']
#  ['Color_Santorini Black' '0.0']
#  ['Color_Santorini Black Metallic' '0.0']
#  ['Color_Silver Gray' '0.0']
#  ['Color_Silver Sky Metallic' '0.0']
#  ['Color_Slingshot Yellow' '0.0']
#  ['Color_Stone Gray' '0.0']
#  ['Color_Summit White' '0.0']
#  ['Color_Super Black' '0.0']
#  ['Color_Triathlon Gray' '0.0']
#  ['Color_White Knuckle Clearcoat' '0.0']
#  ['Color_designo Cardinal Red Metallic' '0.0']
#  ['Color_designo Diamond White' '0.0']
#  ['Color_designo Graphite' '0.0']
#  ['Color_designo Graphite Metallic' '0.0']
#  ['Color_designo Mocha Black' '0.0']
#  ['Color_designo Mocha Black Metallic' '0.0']]

# %% [markdown]
# Obviously, it determined that Cost, vehicle, odometer, year and Class type are the top 5 features. These seem like fairly intuitve results, at least for somebody with a distant notion of what matters when pricing a vehicle.
#
# Let's plot the results next to each other for a better visualization...

# %%
# and plot...
fig = plt.figure(figsize=(15,9))
ax = fig.add_subplot(111)
ind = np.arange(len(included_features))
plt.bar(ind,[float(i) for i in np.array(sorted_scores)[:,1]])
ax.axes.set_xticks(ind)
plt.title('Feature Importances (Mutual Information Regression)')
plt.ylabel('Importance')

plt.show()

# %%
train.shape
# Out:
# (1306, 484)

# %% [markdown]
# ## Feature Pruning
#
# Let's take the top 50, 100, 150 and 200 features to train the random forest regressor model we've been working with. We will wrap the necessary model building and plotting code in functions first.

# %%
# define a function to do the necessary model building....
def getModel(sorted_scores,train,numFeatures):
    included_features = np.array(sorted_scores)[:,0][:numFeatures] # ordered list of important features
    # define the training data X...
    X = train[included_features]
    Y = train[['Price']]
   
    # define the number of estimators to consider
    estimators = [2, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]
    mean_rfrs = []
    std_rfrs_upper = []
    std_rfrs_lower = []
    yt = [i for i in Y['Price']]
    np.random.seed(11111)
    
    # for each number of estimators, fit the model and find the results for 8-fold cross validation
    for i in estimators:
        model = rfr(n_estimators=i,max_depth=None)
        scores_rfr = cross_val_score(model,X,yt,cv=10,scoring='explained_variance')
        mean_rfrs.append(scores_rfr.mean())
        std_rfrs_upper.append(scores_rfr.mean()+scores_rfr.std()*2) # for error plotting
        std_rfrs_lower.append(scores_rfr.mean()-scores_rfr.std()*2) # for error plotting
    return mean_rfrs,std_rfrs_upper,std_rfrs_lower

# define a function to plot the model expected variance results...
def plotResults(mean_rfrs,std_rfrs_upper,std_rfrs_lower,numFeatures):
    fig = plt.figure(figsize=(12,8))
    ax = fig.add_subplot(111)
    ax.plot(estimators,mean_rfrs,marker='o',
           linewidth=4,markersize=12)
    ax.fill_between(estimators,std_rfrs_lower,std_rfrs_upper,
                    facecolor='green',alpha=0.3,interpolate=True)
    ax.set_ylim([-.2,1])
    ax.set_xlim([0,80])
    plt.title('Expected Variance of Random Forest Regressor: Top %d Features'%numFeatures)
    plt.ylabel('Expected Variance')
    plt.xlabel('Trees in Forest')
    plt.grid()
    plt.show()
    return

# %%
# and let's run the regression model fitting for each of the scenarios listed before...
# top 50 features
mean_rfrs,std_rfrs_upper,std_rfrs_lower = getModel(sorted_scores,train,50)
plotResults(mean_rfrs,std_rfrs_upper,std_rfrs_lower,50)

# %%
# and let's run the regression model fitting for each of the scenarios listed before...
# top 100 features
mean_rfrs,std_rfrs_upper,std_rfrs_lower = getModel(sorted_scores,train,100)
plotResults(mean_rfrs,std_rfrs_upper,std_rfrs_lower,100)

# %%
# top 150 features
mean_rfrs,std_rfrs_upper,std_rfrs_lower = getModel(sorted_scores,train,150)
plotResults(mean_rfrs,std_rfrs_upper,std_rfrs_lower,150)

# %%
# top 200 features

mean_rfrs,std_rfrs_upper,std_rfrs_lower = getModel(sorted_scores,train,200)
plotResults(mean_rfrs,std_rfrs_upper,std_rfrs_lower,200)

# %% [markdown]
# #### Random Forest Regression Impressions
#
# It seems like the mean expected variance of the regressions stops improving at around 100 features. The deviation in the expected variance score decreases with increasing features, which is intuitive. The 150-feature and 200-feature results look almost identical, probably because the features are beginning to be insignificant. Let's only consider the top 100 features from here on out.

# %% [markdown]
# ## Building the Output
#
# Now, let's take the best regression model we have and build the prediction output. For this model, we have:
#
# A random forest resgression model, incorporating
# the 100 most prominent features according to an MIR analysis, and
# 100 regressor trees per forest, and
# the default sklearn settings for the rest of the model parameters.
# So let's apply this model to the test data and generate the submission!

# %%
# build the model with the desired parameters...
numFeatures = 100 # the number of features to inlcude
trees = 150 # trees in the forest
included_features = np.array(sorted_scores)[:,0][:numFeatures]

# define the training data X...
X = train[included_features]
Y = train[['Price']]

# transform categorical data if included in X...
for col in list(X):
    if X[col].dtype=='object':
        X = getObjectFeature(X, col)
yt = [i for i in Y['Price']]
np.random.seed(11111)
model = rfr(n_estimators=trees,max_depth=None)
scores_rfr = cross_val_score(model,X,yt,cv=10,scoring='explained_variance')
print('explained variance scores for k=10 fold validation:',scores_rfr)
print("Est. explained variance: %0.2f (+/- %0.2f)" % (scores_rfr.mean(), scores_rfr.std() * 2))
# fit the model
model.fit(X,yt)
# Out:
# explained variance scores for k=10 fold validation: [0.91812999 0.96641184 0.92951675 0.95938668 0.97853005 0.97067765
#  0.98264771 0.44096487 0.96533211 0.97221693]
# Est. explained variance: 0.91 (+/- 0.31)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# ##### The explained variance with the top 100 feature selection is slightly better than the simple feature selection in the first model

# %%
# apply the model to the test data and get the output...

X_test = test[included_features]
# for col in list(X_test):
   # if X_test[col].dtype=='object':
      #  X_test = getObjectFeature(X_test, col, datalength=440)
# print(X_test.head(20))
y_output = model.predict(X_test.fillna(0)) # get the results and fill nan's with 0
print(y_output)
# Out:
# [11.25110349 10.84138409 11.27262535 10.22254336 10.72911257 10.68747836
#  11.0120884  10.9231617  10.17473389  9.8817642  10.94798433  9.57756504
#   9.35648142 10.99682884 10.82750712 10.71758121 10.35848418  9.95777255
#  10.4724127  11.1660553  11.66531261 10.31144436 10.14277691 10.23929373
#  10.69360933 10.74116205 10.78281933 11.27306914 11.2382883  10.39145576
#  10.74120564 11.02069361 11.10478015  9.92580343 11.26821936 11.30292202
#  12.04876423 10.84440725 10.23051342 10.97155946 10.71738346 11.15147336
#  11.44116842 10.60441441 10.80986021 10.69548039 10.45985858 10.25796303
#  10.04093916 10.31140201 10.9931378  10.91400925 10.41396334 10.53388908
#  10.89100621 10.2601223  11.15310833 10.33000309 10.16407622 10.24826733
#  10.9624932   9.85433981 10.45902288 10.57070436 10.73802522 10.71103705
#   9.2374527  10.64487994 10.66848312 10.37860647 10.87384105 10.43286617
#  11.13470586 10.35027666 10.89777203 10.17129919 10.87725483 10.25153533
#  10.70860309 11.2748202  10.95581414 11.03481815 10.67626574 10.17237761
#  10.3736891  10.49957484 11.27777868 10.66870968 10.11785758 10.42434509
#  10.87687851 10.90242012 10.7959943  11.29399684 10.89037679 11.48158741
#  10.15743489 10.06858374  9.84157669 11.55080979 11.26727774 10.4058465
#  11.11890647 10.89437018 10.05017102 10.18084679 10.33136145 10.33230553
#  10.574202    9.63802523 11.2857628  10.69621721  9.20146629 10.20970543
#   64869.22737546  75934.77037402  63230.47539783  88334.72798155
#   58738.31588487  35066.59549204  60492.09758387  65652.71498117
#   47236.54969602  69807.1277988   24402.87585272  44009.65737485
#   57584.47664412  63453.14277842  53001.93794923  28980.97752805
#  115353.998677    61020.69108753  51009.92993505  52125.10280779
#   34305.63245324  42951.46868642  41228.71200094  20112.6521515
#   39001.97607795  35316.31478474  58112.35928563  43149.42099323
#   48949.4909439   39964.08975135  51434.67275052  52554.39342416
#   51528.45253154  33790.39652119 134761.09016811  57715.02909305
#   65500.30482812  44420.86025364  49525.99840161  43461.97238237
#   49099.1303817   47133.42354984  51097.51287594  47161.80034984
#   34848.21834885  47038.20546678  49194.85374613  41232.35977291
#   45997.98638313  91866.74081156  60855.13335491  39928.59071293
#   49604.46934788  39632.10215743  49145.22359995  60916.46620076
#   61312.94784093  61520.24003102  60781.32783545  46668.62374577
#   35999.73707703  43330.77587582  50344.00496091  50924.43376395
#   39445.79353721  40751.69510736  32718.0617388   84642.27686465
#   39919.61662723  47086.99734946  48704.68261292  33751.30656077
#   65270.47255746  65553.94263226  59869.93746376  67912.20298343
#   45137.91775956  12884.68883372  58715.46841051  62973.17415356
#   39223.60122447]

# %%
# define the data frame for the results

Price = pd.DataFrame(y_output, columns=['Pred_Price'])

Test_ = test[['Price','Cost','Odometer', 'Year', 'Age']]
test_data = pd.DataFrame(Test_.reset_index(drop=True))

results = pd.concat([Price['Pred_Price'], test_data],axis=1)
results.head()
# Out:
#      Pred_Price    Price     Cost  Odometer  Year  Age
# 0  76964.803043  76164.0  76514.0      45.0  2018    1
# 1  51092.044819  50841.0  51350.0      18.0  2018    2
# 2  78639.181414  78242.0  78592.0       8.0  2018    3
# 3  27516.562202  29888.0  25673.0   28690.0  2015    4
# 4  45666.148717  55897.0  59004.0    3812.0  2018    4

# %%
# Lets plot a bar graph of the predicted vs actual price

plt.figure(figsize=(15, 9))
plt.title('Predicted Price VS Actual Price', fontsize=20)
plt.xticks(rotation=45)
plt.legend(loc='upper left')
plt.hist(results['Pred_Price'], alpha=0.5, bins=30, label='Predicted Price', color='red')
plt.hist(results['Price'], alpha=0.5, bins=30, label='Price')
plt.legend(loc='upper left')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Lets create a scatterplot of the predicted price versus the actual price of the test data
plt.figure(figsize=(15,9)) 
ax = sns.scatterplot(x="Price", y="Pred_Price", hue="Year", size="Year", data=results)
    
# Set title
plt.title('Histogram of Predicted price VS Actual Price')

# Set x-axis label
plt.xlabel('Actual Price')

# Set y-axis label
plt.ylabel('Predicted price')
# Out:
# Text(0, 0.5, 'Predicted price')

# %%
# and write to output
results.to_csv('Vehicle_Price_Model.csv', index = False)

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Lets try using linear regression to see if we can produce a better prediction model.

# %%
# Load libraries
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import warnings
# Suppress Warning
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %%
# Lets define the independent variable and the target for both the training set and the test set.
# drop the target variable, Price, from the independent variables
included_features = [col for col in list(train)
                    if len([i for i in train[col].T.notnull() if i == True])==1291
                    and col!='Price']

X = train[included_features] # the feature data
Y = train[['Price']] # the target
# and the data for the test...
X_test = test[included_features]
Y_test = test[['Price']]

X.head()
# Out:
#     Year  Age      Cost  Odometer  Carfax Has\nReport_Yes  \
# 28  2018    2   63004.0      41.0                       0
# 31  2018    2   50697.0      35.0                       0
# 33  2018    2   78247.0       9.0                       0
# 38  2018    2   25860.0      15.0                       0
# 50  2019    2  121714.0      14.0                       0
#
#     Carfax Has\nManufacturer\nRecall_Yes  Carfax Has\nWarnings_Yes  \
# 28                                     0                         0
# 31                                     0                         0
# 33                                     0                         0
# 38                                     0                         0
# 50                                     0                         0
#
#     Carfax Has\nProblems_Yes  Vehicle_Acura MDX 3.5L SH-AWD w/Advance Package  \
# 28                         0                                                0
# 31                         0                                                0
# 33                         0                                                0
# 38                         0                                                0
# 50                         0                                                0
#
#     Vehicle_Acura MDX 3.5L w/Technology & Entertainment Pkgs    ...     \
# 28                                                  0           ...
# 31                                                  0           ...
# 33                                                  0           ...
# 38                                                  0           ...
# 50                                                  0           ...
#
#     Color_designo Magno Night Black  \
# 28                                0
# 31                                0
# 33                                0
# 38                                0
# 50                                0
#
#     Color_designo Magno Platinum (Matte Finish)  \
# 28                                            0
# 31                                            0
# 33                                            0
# 38                                            0
# 50                                            0
#
#     Color_designo Magno Selenite Gray  Color_designo Mocha Black  \
# 28                                  0                          0
# 31                                  0                          0
# 33                                  0                          0
# 38                                  0                          0
# 50                                  0                          0
#
#     Color_designo Mocha Black Metallic  Color_designo Mountain Gray Magno  \
# 28                                   0                                  0
# 31                                   0                                  0
# 33                                   0                                  0
# 38                                   0                                  0
# 50                                   0                                  0
#
#     Color_designo Mystic White Metallic  Color_designo Selenite Gray  \
# 28                                    0                            0
# 31                                    0                            0
# 33                                    0                            0
# 38                                    0                            0
# 50                                    0                            0
#
#     Color_designo Shadow Gray Magno  is_train
# 28                                0      True
# 31                                0      True
# 33                                0      True
# 38                                0      True
# 50                                0      True
#
# [5 rows x 483 columns]

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# View the R-Squared score
# The closer to 1 the better
regr.score(X, Y)
# Out:
# 0.9184132017076698

# %%
 # The coefficients
print('Coefficients: \n', regr.coef_)
# Out:
# Coefficients:
#  [[ 9.51415464e-02  7.54844194e-05  1.48134213e-06 -4.64722017e-06
#   -4.52732674e-02  6.80607947e-02 -2.25570725e+06  2.25570721e+06
#   -3.25431969e+05 -3.10992972e+05  1.02046159e+05 -9.93459144e+05
#    3.16871493e+06 -5.01291095e+05 -2.54015126e+05 -2.54014790e+05
#    1.24265970e+06  1.05784049e+05  1.02859561e+06 -1.87037228e+05
#    1.61241702e+05  1.91934686e+05  1.69537691e+04  4.78504672e+04
#    3.50678409e+04  9.17587938e+03 -9.94302691e+04  1.21806927e+05
#   -4.82949833e+02  3.50687433e+04  6.89333236e+04  1.02045469e+05
#    1.02045544e+05  1.02046367e+05 -3.31325424e+04 -3.09779438e+04
#    4.63302249e+04  2.63588951e+04  2.17732630e+04  8.87517452e+04
#    2.94195551e+04 -1.88044520e+04  2.17735923e+04 -1.57931698e+05
#    3.50692114e+04 -2.41379088e+04  5.80502617e+04 -5.04445224e+04
#   -9.10174912e+04  2.93187153e+04 -3.40791381e+04 -3.74426975e+04
#  [ 50886.96952834]
#  [ 32115.58210061]
#  [     0.        ]
#  [ 38981.57694394]
#  [ 66887.42883222]
#  [110782.76658054]
#  [ 32356.80895738]
#  [ 26245.70741247]
#  [ 26450.91913467]
#  [ 41285.43325833]
#  [ 42124.82165764]
#  [ 47369.714074  ]
#  [ 77024.23303658]
#  [ 76054.06690191]
#  [            inf]
#  [ 41748.97342314]
#  [ 59398.84449619]
#  [ 71539.96253364]
#  [ 20957.93441759]
#  [ 76588.66937093]
#  [ 82070.64252096]
#  [187589.25722614]
#  [ 49141.62873845]
#  [ 26722.16646235]
#  [ 53739.95527099]
#  [ 46629.2347015 ]
#  [ 57391.19360248]
#  [ 90149.88622536]
#  [            inf]
#  [ 54564.82743211]
#  [            inf]
#  [ 55829.91101433]
#  [ 28188.77914448]
#  [            inf]
#  [ 24220.575208  ]
#  [ 56534.58893785]
#  [ 57404.43013309]
#  [ 35893.02085693]
#  [ 39502.34680968]
#  [ 55736.40822857]
#  [ 28957.10130061]
#  [ 60745.45023052]
#  [ 27338.16545332]
#  [ 27754.64901484]
#  [ 27840.58245103]
#  [ 57689.31775446]
#  [            inf]
#  [ 33867.73422081]
#  [ 36103.09200111]
#  [ 63020.42366816]
#  [ 45285.87195389]
#  [     0.        ]
#  [ 39027.33466291]
#  [            inf]
#  [ 33610.98296397]
#  [ 49377.55115408]
#  [ 32772.19566277]
#  [     0.        ]
#  [ 30330.74135784]
#  [ 66855.34193844]
#  [ 29751.82394346]
#  [ 54413.20022162]
#  [ 28866.82949314]
#  [ 43909.95065004]
#  [ 77676.57580562]
#  [            inf]
#  [ 59887.96576946]
#  [ 45247.69943404]
#  [ 26539.516515  ]
#  [ 30599.59120577]
#  [ 39729.995423  ]
#  [ 74767.13035904]
#  [ 42345.46725473]
#  [     0.        ]
#  [ 30846.620434  ]
#  [ 54752.93425837]
#  [ 57831.82925841]
#  [ 52289.93941667]
#  [ 77755.01499376]
#  [ 40639.38972046]
#  [            inf]
#  [ 24933.95334474]
#  [     0.        ]
#  [     0.        ]
#  [103382.0395752 ]
#  [ 77584.57872465]
#  [ 29088.54663576]
#  [ 69756.88993667]
#  [ 59021.87128439]
#  [ 24780.88498161]
#  [ 23164.83580258]
#  [ 33746.40427929]
#  [ 26769.24749152]
#  [ 37500.03953739]
#  [     0.        ]
#  [ 73944.46074403]
#  [ 43950.9176896 ]
#  [            inf]
#  [ 25497.63658111]
#  [ 33657.77490469]
#  [ 72450.65599675]
#  [ 56578.0192803 ]
#  [ 31498.11940048]
#  [     0.        ]
#  [     0.        ]
#  [ 43409.4189902 ]
#  [ 31429.22611149]
#  [ 22876.34979249]
#  [ 31109.81901502]
#  [     0.        ]
#  [ 55314.81707174]
#  [            inf]
#  [ 21494.92676127]
#  [            inf]
#  [ 35704.5731311 ]
#  [ 27721.44560648]
#  [ 25315.000665  ]
#  [ 32725.94058781]
#  [ 54343.02257291]
#  [ 45978.99230935]
#  [ 59343.53962705]
#  [ 84551.26768377]
#  [ 45556.54740295]
#  [ 24583.89407761]
#  [     0.        ]
#  [ 32905.65404647]
#  [ 38816.64050804]
#  [ 76132.93967833]
#  [ 38828.37242429]
#  [ 54000.55199818]
#  [ 58948.33489177]
#  [ 57138.08198822]
#  [ 84384.20743347]
#  [ 74643.53155456]
#  [ 36891.92035211]
#  [ 51396.33155761]
#  [     0.        ]
#  [ 31051.72769792]
#  [ 46955.02203435]
#  [ 84215.2848611 ]
#  [ 49262.67211292]
#  [ 30572.69941453]
#  [ 77640.38315343]
#  [ 56978.32874152]
#  [ 29850.44921436]
#  [ 46930.40356965]
#  [ 45427.07724089]
#  [ 85492.13731968]
#  [ 71877.46855413]
#  [            inf]
#  [ 37857.20759844]
#  [ 44033.29119862]
#  [     0.        ]
#  [ 41784.99561397]
#  [ 38036.74292704]
#  [ 43346.82325936]
#  [ 57787.11015247]
#  [ 65383.28687565]
#  [ 41351.50620369]
#  [ 18892.69796883]
#  [ 41100.7657981 ]
#  [ 41562.7240498 ]
#  [ 45624.53546372]
#  [ 88607.99159684]
#  [ 48681.45127746]
#  [ 22498.21762927]
#  [ 56417.03379559]
#  [ 47197.52013318]
#  [ 22685.05111893]
#  [     0.        ]
#  [ 80377.98145071]
#  [ 37490.62973439]
#  [ 57125.66490954]
#  [ 63943.51757593]
#  [            inf]
#  [ 46171.15625854]
#  [ 25919.20306415]
#  [            inf]
#  [            inf]
#  [            inf]
#  [ 38935.87118758]
#  [ 65807.29052613]
#  [ 29832.78783089]
#  [ 35123.68413499]
#  [ 30681.11421424]
#  [ 49453.13765579]
#  [125806.99980067]
#  [ 54868.21089052]
#  [ 44556.90455481]
#  [ 25592.36975864]
#  [ 25189.80545042]
#  [ 65895.16347347]
#  [ 51738.19512138]
#  [ 61167.01165586]
#  [            inf]
#  [ 48128.50483713]
#  [     0.        ]
#  [ 57506.17646458]
#  [ 41144.16358545]
#  [ 51166.08450414]
#  [ 49384.4613628 ]
#  [ 45130.2402159 ]
#  [ 23754.39672413]
#  [ 34854.31490311]
#  [ 31730.33090704]
#  [ 46667.62555268]
#  [ 41533.0181998 ]
#  [ 45849.48223712]
#  [ 60208.29476609]
#  [ 56746.25525731]
#  [ 55578.39484849]
#  [104889.26145084]
#  [ 27449.05424158]
#  [            inf]
#  [ 36423.57424368]
#  [ 56675.42940788]
#  [ 62778.30043855]
#  [ 49803.71116874]
#  [ 48676.50780161]
#  [ 48575.03782592]
#  [            inf]
#  [ 44717.62911499]
#  [ 39655.54237961]
#  [ 49203.78682627]
#  [ 73794.44278442]
#  [ 76809.48965696]
#  [ 49210.6927913 ]
#  [            inf]
#  [ 30323.1934019 ]
#  [ 34365.59991843]
#  [ 33818.1413802 ]
#  [     0.        ]
#  [ 47012.11244071]
#  [ 47200.2962963 ]
#  [ 47438.99435869]
#  [ 44962.53296659]
#  [ 31989.67901874]
#  [ 49222.06672019]
#  [ 56406.4538534 ]
#  [ 55146.04754657]
#  [ 62132.50240546]
#  [ 51689.58507075]
#  [ 52393.55258959]
#  [            inf]
#  [ 34245.1467212 ]
#  [ 55097.62198816]
#  [ 43444.25205483]
#  [ 39214.08178743]
#  [     0.        ]
#  [ 42891.48185731]
#  [ 45215.9870801 ]
#  [ 72576.64168201]
#  [ 42937.21163916]
#  [ 43796.09222075]
#  [ 26785.95253247]
#  [ 28370.03695107]
#  [ 45753.30111293]
#  [ 42600.26847537]
#  [ 30038.62740496]
#  [ 24283.63758899]
#  [ 48158.33409829]
#  [ 46223.17988785]
#  [ 27951.63084116]
#  [ 34797.48422596]
#  [            inf]
#  [ 45548.46592373]
#  [ 57662.89013457]
#  [ 38621.06540597]
#  [ 45122.68647174]
#  [ 30703.9972134 ]
#  [ 45905.10376047]
#  [            inf]
#  [ 32814.5758302 ]
#  [ 42692.67339117]
#  [ 50794.25244157]
#  [ 43520.42236169]
#  [ 25127.57690407]
#  [ 19642.62711463]
#  [ 23595.50344983]
#  [ 26903.9951538 ]
#  [ 46653.19972726]
#  [ 28055.56940164]
#  [ 25841.36619122]
#  [ 31794.40754189]
#  [ 66519.89808667]
#  [ 50349.00915195]
#  [ 48419.58880559]
#  [ 33488.55180965]
#  [ 27227.34798458]
#  [ 40458.51879118]
#  [ 29826.75855929]
#  [ 42535.63750377]
#  [ 42746.83077482]
#  [ 57617.84087559]
#  [ 77087.50273337]
#  [ 57017.46651501]
#  [     0.        ]
#  [ 29507.64633651]
#  [ 46952.73995996]
#  [ 57595.53637531]
#  [ 46146.11257508]
#  [ 49691.12339463]
#  [ 85622.86971683]
#  [ 34043.90337845]
#  [ 50511.86208007]
#  [ 45775.91431788]
#  [ 34726.597281  ]
#  [            inf]
#  [ 33318.44244905]
#  [ 31282.01369901]
#  [ 99591.63375994]
#  [ 38255.55046829]
#  [ 57215.7724199 ]
#  [ 52273.00694377]
#  [            inf]
#  [ 32643.52426016]
#  [     0.        ]
#  [ 32651.48329566]
#  [ 65765.78379264]
#  [ 84489.49340515]
#  [ 33856.70995352]
#  [            inf]
#  [ 65723.23823011]
#  [ 25933.33658012]
#  [ 50690.86149144]
#  [ 43970.50853363]
#  [ 30161.0038849 ]
#  [ 29667.63717451]
#  [ 57272.88824404]
#  [118545.98705261]
#  [ 54780.9542344 ]
#  [ 53494.9442947 ]
#  [ 53198.68582741]
#  [ 57757.33125876]
#  [ 78019.56297097]
#  [     0.        ]
#  [ 85945.7210797 ]
#  [ 54494.81175019]
#  [ 38551.83608814]
#  [ 65552.51402619]
#  [ 62526.06767153]
#  [ 44227.62165631]
#  [     0.        ]
#  [ 29021.88467804]
#  [ 46349.83199069]
#  [ 57457.98992075]
#  [ 56608.41069991]
#  [ 58419.17933461]
#  [ 32065.54766762]
#  [116124.58018868]
#  [ 55481.86624761]
#  [ 52111.03079591]
#  [            inf]
#  [ 36356.01297466]
#  [ 45029.55249822]
#  [ 42764.23655048]
#  [ 21209.46949798]
#  [ 39450.49919133]
#  [ 39171.81755395]
#  [ 56677.63032143]
#  [ 40375.27924918]
#  [ 42293.85464715]
#  [ 42453.56738043]
#  [ 48990.13288554]
#  [ 46306.03853744]
#  [ 44498.527609  ]
#  [ 35056.77002229]
#  [132760.34305804]
#  [ 56764.34048705]
#  [ 55260.63820467]
#  [ 46238.80248654]
#  [ 47826.32726949]
#  [ 46382.40545595]
#  [ 47175.36646261]
#  [ 49442.05534619]
#  [ 49473.95703837]
#  [ 45625.68992065]
#  [ 37627.86211588]
#  [ 45066.8013709 ]
#  [ 47862.21990299]
#  [ 38463.29091933]
#  [ 47155.93649345]
#  [ 76113.71930415]
#  [ 60222.35437326]
#  [ 39401.28237736]
#  [ 45466.74465185]
#  [ 37168.09252341]
#  [ 47312.77435436]
#  [ 57368.58614145]
#  [ 57422.10465116]
#  [ 58047.37175216]
#  [ 60169.24747083]
#  [ 47173.13473562]
#  [ 31956.45611629]
#  [ 44256.70312047]
#  [ 44422.47626779]
#  [ 52559.01244527]
#  [ 40728.02388394]
#  [ 40549.2916005 ]
#  [ 31002.2811517 ]
#  [     0.        ]
#  [ 49061.24126413]
#  [ 26191.48664285]
#  [ 45356.09915137]
#  [ 32074.40997315]
#  [ 61469.88862818]
#  [ 63993.21471487]
#  [ 54842.33571061]
#  [ 60847.94551383]
#  [ 44350.49418787]
#  [ 59747.29412882]
#  [ 55405.94312189]
#  [ 68856.34994498]
#  [ 40931.87340333]]

# %%
# define the data frame for the results

Price = pd.DataFrame(y_output, columns=['y_output'])

# Select features from the test data and create a new dataframe and reset the index
Test_ = test[['Price','Odometer', 'Year', 'Age']]
test_data = pd.DataFrame(Test_.reset_index(drop=True))

# Concatenate the Prediction and the new test dataframe
results = pd.concat([Price['y_output'], test_data],axis=1)
results.head()
# Out:
#        y_output    Price  Odometer  Year  Age
# 0  80670.922766  76164.0      45.0  2018    1
# 1  57867.400900  50841.0      18.0  2018    2
# 2  83342.022103  78242.0       8.0  2018    3
# 3  27741.127441  29888.0   28690.0  2015    4
# 4  57038.984789  55897.0    3812.0  2018    4

# %%
# Lets create a scatterplot of the predicted price versus the actual price of the test data
plt.figure(figsize=(15,9)) 
ax = sns.scatterplot(x="Price", y="y_output", hue="Year", size="Year", data=results)
    
# Set title
plt.title('Histogram of Predicted price VS Actual Price')

# Set x-axis label
plt.xlabel('Actual Price')

# Set y-axis label
plt.ylabel('Predicted price')
# Out:
# Text(0, 0.5, 'Predicted price')

# %% [markdown]
# As you can see from the scatter plot the prediction model is not good enough. There are several predictions that are far off from the 45 degree intersection.

# %% [markdown]
# ## Conclusion
#
# The predicted price in the random forest model was pretty close to the actual test dataset versus the linear regression. When I did the feature ranking of the dataset set, The best performing model was the random forest with 100 features and 100 trees, with an acuracy of 91%.
#
# I believe the model can serve as a good pricing tool for the dealership because it follows in the dealership current pattern of pricing based on the recently sold inventory.
#
# For this modeling, I chose the random forest regression model because it combines multiple decisions tress in determining the final output rather than relying on individual trees which i feel is perfect to create the model. I also chose to use linear regression because its a commonly used type of predictive analysis.
#
# There were a few issues with the data, there was alot of missing values in multiple fields which ended up causing a reduction in the data size when some of the fields and rows were dropped. Filling in the missing values in some of the fields would have skewed the data, which would affect the model. I believe if i created a model based on sold vehicle dataset from several other dealerships in the area, the model would be more robust and produce a more accurate predictive model.
